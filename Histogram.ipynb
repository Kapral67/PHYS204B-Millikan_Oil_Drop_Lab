# %%
library(ggplot2)

# %%
data <- read.csv("data.csv")

# %%
data2 <- read.csv("data2.csv")

# %% [markdown]
# ---
# ### Using Class Averages

# %%
ggplot(data=data, aes(q)) + geom_histogram(binwidth=0.6)
# Out:
# plot without title

# %% [markdown]
# ### Using Class Raw Data

# %%
ggplot(data=data2, aes(q)) + geom_histogram(binwidth=0.6)
# Out:
# plot without title
